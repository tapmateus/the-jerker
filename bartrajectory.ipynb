# %% [markdown]
# ## Libraries

# %%
import numpy as np
import cv2
from ultralytics import YOLO
#from collections import defaultdict

# %% [markdown]
# ## Bar Trajectory

# %%
## object detection and tracking with YOLOv8 pre-trainer models to trace the barbell trajectory

def bar_path(video):

    # load the YOLOv8n model
    model = YOLO('yolov8n.pt')
    
    # open the video file
    video_path = video
    cap = cv2.VideoCapture(video_path)
    
    # store the track history
    track_history = defaultdict(lambda: []) 
    
    # loop through the video frames
    while cap.isOpened():
        # read a frame from the video
        success, frame = cap.read()
        
        if success:
            # run YOLOv8 tracking on the frame, persisting tracks between frames
            results = model.track(frame, persist=True)
            
            # get the boxes and track IDs
            boxes = results[0].boxes.xywh.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()
    
            # visualize the results on the frame
            annotated_frame = results[0].plot()
    
            # plot the tracks
            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                if len(track) > 500:  # retain line for 500 frames
                    track.pop(0)
    
                # draw the tracking lines
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=5)
    
            # display the annotated frame
            cv2.imshow("Bar Trajectory", annotated_frame)
    
            # break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            # break the loop if the end of the video is reached
            break
    
    # release the video capture object and close the display window
    cap.release()
    cv2.destroyAllWindows()

    return 

bar_path('video.mp4')
# Out:
# 0: 640x640 1 person, 1 frisbee, 90.8ms
# Speed: 4.6ms preprocess, 90.8ms inference, 10.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 86.9ms
# Speed: 2.4ms preprocess, 86.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 73.5ms
# Speed: 2.4ms preprocess, 73.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.4ms
# Speed: 2.3ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 72.4ms
# Speed: 2.6ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.3ms
# Speed: 2.1ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.5ms
# Speed: 2.1ms preprocess, 69.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.8ms
# Speed: 3.1ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 73.2ms
# Speed: 3.1ms preprocess, 73.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 71.7ms
# Speed: 2.9ms preprocess, 71.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.0ms
# Speed: 3.1ms preprocess, 68.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 67.9ms
# Speed: 2.4ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.8ms
# Speed: 2.4ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.7ms
# Speed: 2.2ms preprocess, 70.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 72.3ms
# Speed: 2.4ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 71.3ms
# Speed: 2.5ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.8ms
# Speed: 1.9ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.7ms
# Speed: 2.2ms preprocess, 69.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.6ms
# Speed: 2.2ms preprocess, 69.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.9ms
# Speed: 2.4ms preprocess, 70.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 77.0ms
# Speed: 2.6ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.4ms
# Speed: 2.4ms preprocess, 70.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 72.9ms
# Speed: 2.2ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.3ms
# Speed: 2.4ms preprocess, 69.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.6ms
# Speed: 2.4ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 71.3ms
# Speed: 2.0ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.2ms
# Speed: 2.1ms preprocess, 69.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 78.6ms
# Speed: 2.2ms preprocess, 78.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 79.5ms
# Speed: 2.4ms preprocess, 79.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 71.4ms
# Speed: 1.9ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.9ms
# Speed: 2.3ms preprocess, 70.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 87.5ms
# Speed: 2.4ms preprocess, 87.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 73.2ms
# Speed: 2.2ms preprocess, 73.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 71.3ms
# Speed: 1.8ms preprocess, 71.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.9ms
# Speed: 1.9ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 72.5ms
# Speed: 2.1ms preprocess, 72.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 72.7ms
# Speed: 2.1ms preprocess, 72.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 sports ball, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 sports ball, 69.9ms
# Speed: 2.2ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 sports ball, 69.0ms
# Speed: 1.9ms preprocess, 69.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 sports ball, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 sports ball, 75.9ms
# Speed: 2.1ms preprocess, 75.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 88.1ms
# Speed: 2.4ms preprocess, 88.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.6ms
# Speed: 2.1ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 75.4ms
# Speed: 2.2ms preprocess, 75.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 73.3ms
# Speed: 2.3ms preprocess, 73.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.5ms
# Speed: 2.1ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 73.2ms
# Speed: 2.1ms preprocess, 73.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 75.8ms
# Speed: 1.8ms preprocess, 75.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 66.7ms
# Speed: 2.4ms preprocess, 66.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.9ms
# Speed: 2.2ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 67.6ms
# Speed: 1.9ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 67.9ms
# Speed: 2.2ms preprocess, 67.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.9ms
# Speed: 2.4ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.8ms
# Speed: 2.2ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.6ms
# Speed: 1.9ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 67.2ms
# Speed: 2.3ms preprocess, 67.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.6ms
# Speed: 2.2ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.2ms
# Speed: 2.0ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.3ms
# Speed: 2.1ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.4ms
# Speed: 2.2ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.5ms
# Speed: 2.4ms preprocess, 70.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.8ms
# Speed: 2.1ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.5ms
# Speed: 2.2ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.1ms
# Speed: 2.2ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 66.5ms
# Speed: 2.3ms preprocess, 66.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.6ms
# Speed: 2.4ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.2ms
# Speed: 2.6ms preprocess, 69.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.6ms
# Speed: 2.4ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.4ms
# Speed: 2.1ms preprocess, 68.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.7ms
# Speed: 2.3ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.2ms
# Speed: 2.2ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.2ms
# Speed: 2.4ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.6ms
# Speed: 2.2ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.4ms
# Speed: 2.1ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 67.4ms
# Speed: 2.3ms preprocess, 67.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 68.7ms
# Speed: 2.2ms preprocess, 68.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 71.9ms
# Speed: 2.3ms preprocess, 71.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 70.2ms
# Speed: 2.2ms preprocess, 70.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.2ms
# Speed: 2.1ms preprocess, 69.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 frisbee, 69.4ms
# Speed: 2.3ms preprocess, 69.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 68.6ms
# Speed: 2.1ms preprocess, 68.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 68.6ms
# Speed: 2.4ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 69.6ms
# Speed: 2.3ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 72.1ms
# Speed: 2.6ms preprocess, 72.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 71.0ms
# Speed: 2.3ms preprocess, 71.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 94.3ms
# Speed: 1.9ms preprocess, 94.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 80.4ms
# Speed: 1.8ms preprocess, 80.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 93.1ms
# Speed: 2.6ms preprocess, 93.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 84.3ms
# Speed: 2.0ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2 frisbees, 101.5ms
# Speed: 3.2ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
